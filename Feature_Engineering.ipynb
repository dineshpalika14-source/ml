# %% [markdown]
# # Feature_Engineering

# %% [markdown]
# - Feature Engineering is the process of converting raw data into meaningful numerical features so that a machine learning model can understand patterns and make better prediction

# %% [markdown]
# # 1.Feature exploration

# %% [markdown]
# - the process of analysing and visualizing features to uncover patterns,distributions,correlations and potential issue the dataset before applying machine learniung

# %% [markdown]
# # 2.Feature creation

# %% [markdown]
# - The Procress of generating new meaningful features from existing data using domain Knowledge features from existing data using domain knowledge or mathematical operations to help the model learn better patterns.

# %% [markdown]
# # 3.Feature Encoding

# %% [markdown]
# - The Process of converting Categorical or non-numeric features into numeric form so machine learning models can process them effectively.

# %% [markdown]
# # 4.Feature Scaling

# %% [markdown]
# - The process of transforming numerical features to a standard range or distribution so that no feature dominates the learning process due to its scale.

# %% [markdown]
# # 5.feature selection

# %% [markdown]
# - the process of identifying and keeping only the most relevant features while removing irrelevant or redundant ones to improve model performance  and reduce overfitting

# %% [markdown]
# # Feature Creation (Adds Intelligence):

# %% [markdown]
# - Definition:
#        Feature Creation is the process of creating new features from existing data using domain knowledge and mathematical operations to help the model learn better patterns.

# %% [markdown]
# # Wht it "Adds Intelligence":

# %% [markdown]
# - Raw data may not show hidden relationships
# - New features provide extra information
# - Models cannot think logically - feature guide learning

# %% [markdown]
# # Common Types of Feature Creation:

# %% [markdown]
# - Domain-based feature (real-world logic)
# - Mathematical combinations (sum, average, ratio)
# - Interaction features (combined effect of features)
# - Polynomial Features (non-linear relationships)

# %% [markdown]
# # Example:

# %% [markdown]
# - Total_Marks = Math + Science
# - Efficiency = Total_Marks / Study_Hours

# %% [markdown]
# # impact on model

# %% [markdown]
# - Improves accuray
# - Helps models capture complex patterns
# - Makes simple models perform bette

# %% [markdown]
# # Feature creation

# %%
import pandas as pd
df = pd.DataFrame({
    "Study_Hours": [2, 4, 6, 8, 10],
    "Attendance": [60, 70, 80, 90, 95],
    "Maths": [46, 55, 65, 75, 80],
    "Science": [42, 58, 68, 78, 88]
})
df
# Out:
#    Study_Hours  Attendance  Maths  Science
# 0            2          60     46       42
# 1            4          70     55       58
# 2            6          80     65       68
# 3            8          90     75       78
# 4           10          95     80       88

# %% [markdown]
# # Domain based feature

# %%
df["Total_marks"] = df["Maths"] + df["Science"]
df
# Out:
#    Study_Hours  Attendance  Maths  Science  Total_marks
# 0            2          60     46       42           88
# 1            4          70     55       58          113
# 2            6          80     65       68          133
# 3            8          90     75       78          153
# 4           10          95     80       88          168

# %% [markdown]
# # Mathematical Feature:

# %%
df["Marks_per_Hour"] = df["Total_marks"] / df["Study_Hours"]
df
# Out:
#    Study_Hours  Attendance  Maths  Science  Total_marks  Marks_per_Hour
# 0            2          60     46       42           88       44.000000
# 1            4          70     55       58          113       28.250000
# 2            6          80     65       68          133       22.166667
# 3            8          90     75       78          153       19.125000
# 4           10          95     80       88          168       16.800000

# %% [markdown]
# # Interaction Feature :

# %%
df["Study_Atendance_Interaction"] = df["Study_Hours"] * df["Attendance"]
df
# Out:
#    Study_Hours  Attendance  Maths  Science  Total_marks  Marks_per_Hour  \
# 0            2          60     46       42           88       44.000000
# 1            4          70     55       58          113       28.250000
# 2            6          80     65       68          133       22.166667
# 3            8          90     75       78          153       19.125000
# 4           10          95     80       88          168       16.800000
#
#    Study_Atendance_Interaction
# 0                          120
# 1                          280
# 2                          480
# 3                          720
# 4                          950

# %% [markdown]
# # Polynomial Feature:

# %%
df["Study_Hours_Squared"] = df["Study_Hours"] ** 2
df
# Out:
#    Study_Hours  Attendance  Maths  Science  Total_marks  Marks_per_Hour  \
# 0            2          60     46       42           88       44.000000
# 1            4          70     55       58          113       28.250000
# 2            6          80     65       68          133       22.166667
# 3            8          90     75       78          153       19.125000
# 4           10          95     80       88          168       16.800000
#
#    Study_Atendance_Interaction  Study_Hours_Squared
# 0                          120                    4
# 1                          280                   16
# 2                          480                   36
# 3                          720                   64
# 4                          950                  100

# %% [markdown]
#  # Feature selection (Remove Noise):

# %% [markdown]
# #### Definition:
#       - Feature selection is the process of selecting only relevant features and removing irrelevant or redundant ones to improve performance
#
# ### why it "removes noise":
# - Too many features confuse the model
# - Irrelevant features cause overfitting
# - Noise reduces prediction accuracy
#
# #### types of feature selection:
# - Filter methods(correlation,chi-square)
# - Wrapper methods(forward,backward,RFE)
# - Embedded methods(Lasso,tree-based models)
#
# #### Example:
# - Removing weakly correlation features
# - Dropping features with zero imporatnce
# - Selection top features using REF(Recursive Feature Elimination )
#
# #### impact on model:
#
# - Reduce overfitting
# - Improves generalization
# - Speeds up training

# %%
df
# Out:
#    Study_Hours  Attendance  Maths  Science  Total_marks  Marks_per_Hour  \
# 0            2          60     46       42           88       44.000000
# 1            4          70     55       58          113       28.250000
# 2            6          80     65       68          133       22.166667
# 3            8          90     75       78          153       19.125000
# 4           10          95     80       88          168       16.800000
#
#    Study_Atendance_Interaction  Study_Hours_Squared
# 0                          120                    4
# 1                          280                   16
# 2                          480                   36
# 3                          720                   64
# 4                          950                  100

# %%
x = df.drop("Science" , axis = 1)
y = df["Science"]
x
# Out:
#    Study_Hours  Attendance  Maths  Total_marks  Marks_per_Hour  \
# 0            2          60     46           88       44.000000
# 1            4          70     55          113       28.250000
# 2            6          80     65          133       22.166667
# 3            8          90     75          153       19.125000
# 4           10          95     80          168       16.800000
#
#    Study_Atendance_Interaction  Study_Hours_Squared
# 0                          120                    4
# 1                          280                   16
# 2                          480                   36
# 3                          720                   64
# 4                          950                  100

# %%
y
# Out:
# 0    42
# 1    58
# 2    68
# 3    78
# 4    88
# Name: Science, dtype: int64

# %% [markdown]
# # Filter Methods(Statistics - Based):

# %% [markdown]
# - correlation Method

# %%
df.corr()["Science"].sort_values(ascending = False)
# Out:
# Science                        1.000000
# Total_marks                    0.998562
# Study_Hours                    0.994309
# Attendance                     0.994110
# Maths                          0.992572
# Study_Atendance_Interaction    0.983804
# Study_Hours_Squared            0.958102
# Marks_per_Hour                -0.956224
# Name: Science, dtype: float64

# %%
corr = df.corr()["Science"].abs()
corr
# Out:
# Study_Hours                    0.994309
# Attendance                     0.994110
# Maths                          0.992572
# Science                        1.000000
# Total_marks                    0.998562
# Marks_per_Hour                 0.956224
# Study_Atendance_Interaction    0.983804
# Study_Hours_Squared            0.958102
# Name: Science, dtype: float64

# %%
selected_features = corr[corr > 0.8].index
selected_features
# Out:
# Index(['Study_Hours', 'Attendance', 'Maths', 'Science', 'Total_marks',
#        'Marks_per_Hour', 'Study_Atendance_Interaction', 'Study_Hours_Squared'],
#       dtype='object')
